# %%
import pandas as pd

# %%
column_names = ["Runtime min", "Runtime avg", "Runtime max",
                "Read min", "Read avg", "Read max",
                "Write min", "Write avg", "Write max",
                "Tx per block min", "Tx per block avg", "Tx per block max"]
df = pd.DataFrame(columns=column_names)

# %%
df.loc[10] = [13450000, 57027250, 72936000, 13427, 23032, 26389, 0, 4499, 6205, 371, 144, 68]
df.loc[20] = [13490000, 101302250, 131956000, 13467, 32755, 39339, 0, 9127, 12375, 370, 120, 37]
df.loc[30] = [13530000, 145577250, 190976000, 13507, 42477, 52289, 0, 13754, 18545, 369, 111, 26]
df.loc[40] = [13570000, 189852250, 249996000, 13547, 52200, 65239, 0, 18382, 24715, 368, 107, 20]
df.loc[50] = [13610000, 234127250, 304867000, 13587, 61922, 77726, 0, 23009, 30268, 367, 103, 16]
df.loc[60] = [13650000, 278402250, 368036000, 13627, 71645, 91139, 0, 27637, 37055, 366, 101, 13]
df.loc[70] = [13690000, 322677250, 427056000, 13667, 81367, 104089, 0, 32264, 43225, 365, 99, 11]
df.loc[80] = [13730000, 366952250, 481927000, 13707, 91090, 116576, 0, 36892, 48778, 364, 98, 10]
df.loc[90] = [13770000, 411227250, 545096000, 13747, 100812, 129989, 0, 41519, 55565, 363, 97, 9]

df.loc[100] = [13812000, 455504250, 599969000, 13789, 110537, 142478, 0, 46147, 61118, 362, 96, 8]
df.loc[200] = [14312000, 898354250, 1190269000, 14289, 207862, 272078, 0, 92422, 122818, 349, 90, 4]
df.loc[300] = [14812000, 1341204250, 1784718000, 14789, 305187, 402141, 0, 138697, 185135, 337, 85, 2]
df.loc[400] = [15312000, 1784054250, 2370869000, 15289, 402512, 531278, 0, 184972, 246218, 326, 83, 2]
df.loc[500] = [15812000, 2226904250, 2961169000, 15789, 499837, 660878, 0, 231247, 307918, 316, 79, 1]
df.loc[600] = [16312000, 2669754250, 3555618000, 16289, 597162, 790941, 0, 277522, 370235, 306, 77, 1]
df.loc[700] = [16812000, 3112604250, 4141769000, 16789, 694487, 920078, 0, 323797, 431318, 297, 75, 1]
df.loc[800] = [17312000, 3555454250, 4732069000, 17289, 791812, 1049678, 0, 370072, 493018, 288, 72, 1]

# %%
df
# Out:
#     Runtime min Runtime avg Runtime max Read min Read avg Read max Write min  \
# 10     13450000    57027250    72936000    13427    23032    26389         0
# 20     13490000   101302250   131956000    13467    32755    39339         0
# 30     13530000   145577250   190976000    13507    42477    52289         0
# 40     13570000   189852250   249996000    13547    52200    65239         0
# 50     13610000   234127250   304867000    13587    61922    77726         0
# 60     13650000   278402250   368036000    13627    71645    91139         0
# 70     13690000   322677250   427056000    13667    81367   104089         0
# 80     13730000   366952250   481927000    13707    91090   116576         0
# 90     13770000   411227250   545096000    13747   100812   129989         0
# 100    13812000   455504250   599969000    13789   110537   142478         0
# 200    14312000   898354250  1190269000    14289   207862   272078         0
# ...

# %%
df[['Runtime min', 'Runtime avg', 'Runtime max']].iloc[0:9].plot()

# %%
df[['Runtime min', 'Runtime avg', 'Runtime max']].iloc[9:].plot()

# %%
df[['Read min', 'Read avg', 'Read max']].iloc[0:9].plot()

# %%
df[['Read min', 'Read avg', 'Read max']].iloc[9:].plot()

# %%
df[['Write min', 'Write avg', 'Write max']].iloc[0:9].plot()

# %%
df[['Write min', 'Write avg', 'Write max']].iloc[9:].plot()

# %%
df[['Tx per block min', 'Tx per block avg', 'Tx per block max']].iloc[0:9].plot()

# %%
df[['Tx per block min', 'Tx per block avg', 'Tx per block max']].iloc[9:].plot()
